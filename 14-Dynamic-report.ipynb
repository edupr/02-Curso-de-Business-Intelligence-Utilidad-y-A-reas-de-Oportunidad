# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Leer Excel

# %%
df_report = pd.read_excel('./14-caso-practico-2-data.xlsx')

# %%
df_report.head()
# Out:
#        Invoice Branch        City    Type  Gender                Category  \
# 0  750-67-8428      A  Nueva York  Member  Female       Health and beauty
# 1  226-31-3081      C     Houston  Normal  Female  Electronic accessories
# 2  631-41-3108      A  Nueva York  Normal    Male      Home and lifestyle
# 3  123-19-1176      A  Nueva York  Member    Male       Health and beauty
# 4  373-73-7910      A  Nueva York  Normal    Male       Sports and travel
#
#      Cost      Sale                 Date  Year  Month  Day      Date2  \
# 0  522.83  548.9715  2019-05-01 00:00:00  2019      1    5 2019-01-05
# 1   76.40   80.2200  2019-08-03 00:00:00  2019      3    8 2019-03-08
# 2  324.31  340.5255  2019-03-03 00:00:00  2019      3    3 2019-03-03
# 3  465.76  489.0480            1/27/2019  2019      1   27 2019-01-27
# 4  604.17  634.3785  2019-08-02 00:00:00  2019      2    8 2019-02-08
#
#        Time      Payment  Review
# 0  13:08:00      Ewallet     9.1
# ...

# %%
df_report.describe()
# Out:
#              Cost         Sale    Year        Month          Day      Review
# count  1000.00000  1000.000000  1000.0  1000.000000  1000.000000  1000.00000
# mean    307.58738   322.966749  2019.0     1.993000    15.256000     6.97270
# std     234.17651   245.885335     0.0     0.835254     8.693563     1.71858
# min      10.17000    10.678500  2019.0     1.000000     1.000000     4.00000
# 25%     118.49750   124.422375  2019.0     1.000000     8.000000     5.50000
# 50%     241.76000   253.848000  2019.0     2.000000    15.000000     7.00000
# 75%     448.90500   471.350250  2019.0     3.000000    23.000000     8.50000
# max     993.00000  1042.650000  2019.0     3.000000    31.000000    10.00000

# %% [markdown]
# * Hay 1000 elementos.
# * Costo medio: $307.58
# * Venta media: $322.96
# * Año de más ventas: 2019
# * Mes de más ventas: febrero
# * Calificación media: 6.97

# %% [markdown]
# ### Las entradas que tienen una calificación perfecta (de 10):

# %%
df_report[df_report['Review'] == 10]
# Out:
#          Invoice Branch        City    Type  Gender                Category  \
# 60   285-68-5083      C     Houston  Member  Female       Sports and travel
# 62   347-34-2234      B     Chicago  Member  Female       Sports and travel
# 159  423-57-2993      B     Chicago  Normal    Male       Sports and travel
# 387  725-56-0833      A  Nueva York  Normal  Female       Health and beauty
# 853  866-70-2814      B     Chicago  Normal  Female  Electronic accessories
#
#           Cost       Sale       Date  Year  Month  Day     Date2      Time  \
# 60     $74.22     $77.93   2/15/2019  2019      2   15  15/02/19  17:47:00
# 62    $495.63    $520.41    02/03/19  2019      2    3  03/02/19  13:40:00
# 159   $560.34    $588.36   3/27/2019  2019      3   27  27/03/19  19:18:00
# 387   $323.20    $339.36   2/20/2019  2019      2   20  20/02/19  16:49:00
# 853   $527.90    $554.30   2/25/2019  2019      2   25  25/02/19  11:58:00
#
#          Payment  Review
# 60   Credit card    10.0
# ...

# %% [markdown]
# Graficar relaciones:

# %%
sns.scatterplot(data=df_filtered,x='Month',y='Sale')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-1201eaead873> in <module>
# ----> 1 sns.scatterplot(data=df_filtered,x='Month',y='Sale')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799
#     800     variables = _ScatterPlotter.get_semantics(locals())
# --> 801     p = _ScatterPlotter(
#     802         data=data, variables=variables,
# ...

# %%
sns.pairplot(data=df_filtered, hue='Category', palette='coolwarm', corner=True)
plt.show()

# %%
sns.heatmap(df_filtered)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-038d0db4257e> in <module>
# ----> 1 sns.heatmap(df_filtered)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# ...
